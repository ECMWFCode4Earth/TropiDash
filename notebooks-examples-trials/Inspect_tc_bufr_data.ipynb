# %% [markdown]
# # Using pdbufr to inspect tropical cyclone data

# %%
import pdbufr
from ecmwf.opendata import Client

# %% [markdown]
# ## Download tropical cyclone data from ECMWF open data catalogue
#
# Setting source to azure will give you older data.
#
# **date** is the start date of the forecast.
# **step** in this case step 240 actually **has all the available steps inside**.
#
# The next cell will download yesterday's forecast and save it in the file called **"tc_test.bufr"**. For older data, just put the date in format YYYYMMDD (20221124 for example)

# %%
client = Client(source="azure")

client.retrieve(
    date=-1,
    time=0,
    stream="oper",
    type="tf",
    step=240,
    target="tc_test.bufr",
)

# %% [markdown]
# # How to read bufr data
# I am not an expert but this is what I've figured out today....
#
# To check which stors are inside you use stormIdentifier key. We can see that in this data I used today (27 July 2023) there is only one tropical cyclone 07W.

# %%
df = pdbufr.read_bufr("tc_test.bufr",
    columns=("stormIdentifier"))
df["stormIdentifier"].unique()
# Out:
# array(['07W'], dtype=object)

# %% [markdown]
# It looks like that if there is more cyclones you can filter out by this key, for example like in the next cell. But we now have only one storm so it wouldn't do much.

# %%
df = pdbufr.read_bufr("tc_test.bufr",
    columns=("stormIdentifier", "latitude", "longitude",
             "pressureReducedToMeanSeaLevel"),
    filters={"stormIdentifier": "07W"})
df.head(24)
# Out:
#    stormIdentifier  latitude  longitude  pressureReducedToMeanSeaLevel
# 0              07W      18.8      121.1                        96700.0
# 1              07W      19.2      121.0                        96700.0
# 2              07W      19.6      120.6                        96900.0
# 3              07W      20.2      120.3                        96700.0
# 4              07W      20.7      119.8                        96700.0
# 5              07W      21.4      119.3                        95800.0
# 6              07W      21.9      118.8                        95300.0
# 7              07W      23.0      118.4                        95200.0
# 8              07W      24.2      118.1                        95300.0
# 9              07W      25.4      117.4                        97200.0
# 10             07W      27.3      117.0                        98400.0
# 11             07W      28.7      116.2                        98900.0
# 12             07W      30.1      116.0                        99300.0
# 13             07W      31.9      115.5                        99300.0
# 14             07W      32.5      114.6                        99500.0
# 15             07W      33.1      113.9                        99400.0
# 16             07W      33.4      114.0                        99500.0
# 17             07W      34.1      114.7                        99500.0
# 18             07W      35.0      114.1                        99700.0
# 19             07W      35.9      114.3                        99600.0
# 20             07W      35.0      112.7                       100000.0
# 21             07W       NaN        NaN                            NaN
# 22             07W       NaN        NaN                            NaN
# 23             07W      36.1      110.3                       100300.0

# %% [markdown]
# It also looks like that except storIdentifier, latitude and longitude you can only read one more column. So you can't read pressure/wind etc at the same time. Why is this, is beyond me.

# %%
df1 = pdbufr.read_bufr("tc_test.bufr",
    columns=("stormIdentifier", "latitude", "longitude",
             "pressureReducedToMeanSeaLevel" ))
df1.head(25)
# Out:
#    stormIdentifier  latitude  longitude  pressureReducedToMeanSeaLevel
# 0              07W      18.8      121.1                        96700.0
# 1              07W      19.2      121.0                        96700.0
# 2              07W      19.6      120.6                        96900.0
# 3              07W      20.2      120.3                        96700.0
# 4              07W      20.7      119.8                        96700.0
# 5              07W      21.4      119.3                        95800.0
# 6              07W      21.9      118.8                        95300.0
# 7              07W      23.0      118.4                        95200.0
# 8              07W      24.2      118.1                        95300.0
# 9              07W      25.4      117.4                        97200.0
# 10             07W      27.3      117.0                        98400.0
# 11             07W      28.7      116.2                        98900.0
# 12             07W      30.1      116.0                        99300.0
# 13             07W      31.9      115.5                        99300.0
# 14             07W      32.5      114.6                        99500.0
# 15             07W      33.1      113.9                        99400.0
# 16             07W      33.4      114.0                        99500.0
# 17             07W      34.1      114.7                        99500.0
# 18             07W      35.0      114.1                        99700.0
# 19             07W      35.9      114.3                        99600.0
# 20             07W      35.0      112.7                       100000.0
# 21             07W       NaN        NaN                            NaN
# 22             07W       NaN        NaN                            NaN
# 23             07W      36.1      110.3                       100300.0

# %% [markdown]
# To see what keys are available you can read 'flat' bufr. This means it will just give you ALL they keys and values.
#
# The first 13 are common for all the points. Then it starts to show the data from analysis and forecast. This is no where near simple.

# %%
df = pdbufr.read_bufr("tc_test.bufr", columns="data", flat=True)
df.T.head(13)
# Out:
#                                                       0
# subsetNumber                                          1
# #1#centre                                            98
# #1#subCentre                                       None
# #1#generatingApplication                              1
# #1#stormIdentifier                                  07W
# #1#longStormName                                DOKSURI
# #1#techniqueForMakingUpInitialPerturbations           2
# #1#ensembleMemberNumber                              52
# #1#ensembleForecastType                               0
# #1#year                                            2023
# #1#month                                              7
# #1#day                                               26
# #1#hour                                               0

# %% [markdown]
# ## This is the analysis:

# %%
df.T[14:64]
# Out:
#                                                            0
# #1#meteorologicalAttributeSignificance                     1
# #1#latitude                                             18.8
# #1#longitude                                           121.4
# #2#meteorologicalAttributeSignificance                     5
# #2#latitude                                             18.8
# #2#longitude                                           121.1
# #1#pressureReducedToMeanSeaLevel                     96700.0
# #3#meteorologicalAttributeSignificance                     3
# #3#latitude                                             19.1
# #3#longitude                                           121.5
# #1#windSpeedAt10M                                       28.3
# #1#windSpeedThreshold                                     18
# #1#bearingOrAzimuth                                      0.0
# #2#bearingOrAzimuth                                     90.0
# #1#effectiveRadiusWithRespectToWindSpeedsAboveT...  376000.0
# #3#bearingOrAzimuth                                     90.0
# #4#bearingOrAzimuth                                    180.0
# #2#effectiveRadiusWithRespectToWindSpeedsAboveT...  385200.0
# #5#bearingOrAzimuth                                    180.0
# #6#bearingOrAzimuth                                    270.0
# #3#effectiveRadiusWithRespectToWindSpeedsAboveT...  279700.0
# #7#bearingOrAzimuth                                    270.0
# #8#bearingOrAzimuth                                      0.0
# #4#effectiveRadiusWithRespectToWindSpeedsAboveT...  370400.0
# #2#windSpeedThreshold                                     26
# #9#bearingOrAzimuth                                      0.0
# #10#bearingOrAzimuth                                    90.0
# #5#effectiveRadiusWithRespectToWindSpeedsAboveT...   72200.0
# #11#bearingOrAzimuth                                    90.0
# #12#bearingOrAzimuth                                   180.0
# #6#effectiveRadiusWithRespectToWindSpeedsAboveT...       0.0
# #13#bearingOrAzimuth                                   180.0
# #14#bearingOrAzimuth                                   270.0
# #7#effectiveRadiusWithRespectToWindSpeedsAboveT...       0.0
# #15#bearingOrAzimuth                                   270.0
# #16#bearingOrAzimuth                                     0.0
# #8#effectiveRadiusWithRespectToWindSpeedsAboveT...       0.0
# #3#windSpeedThreshold                                     33
# #17#bearingOrAzimuth                                     0.0
# #18#bearingOrAzimuth                                    90.0
# #9#effectiveRadiusWithRespectToWindSpeedsAboveT...       0.0
# #19#bearingOrAzimuth                                    90.0
# #20#bearingOrAzimuth                                   180.0
# #10#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #21#bearingOrAzimuth                                   180.0
# #22#bearingOrAzimuth                                   270.0
# #11#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #23#bearingOrAzimuth                                   270.0
# #24#bearingOrAzimuth                                     0.0
# #12#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0

# %% [markdown]
# This is data for step 6 (don't ask me how I deducted this...)

# %%
df.T[65:113]
# Out:
#                                                            0
# #1#timePeriod                                              6
# #4#meteorologicalAttributeSignificance                     1
# #4#latitude                                             19.2
# #4#longitude                                           121.0
# #2#pressureReducedToMeanSeaLevel                     96700.0
# #5#meteorologicalAttributeSignificance                     3
# #5#latitude                                             19.5
# #5#longitude                                           121.3
# #2#windSpeedAt10M                                       29.3
# #4#windSpeedThreshold                                     18
# #25#bearingOrAzimuth                                     0.0
# #26#bearingOrAzimuth                                    90.0
# #13#effectiveRadiusWithRespectToWindSpeedsAbove...  426000.0
# #27#bearingOrAzimuth                                    90.0
# #28#bearingOrAzimuth                                   180.0
# #14#effectiveRadiusWithRespectToWindSpeedsAbove...  374100.0
# #29#bearingOrAzimuth                                   180.0
# #30#bearingOrAzimuth                                   270.0
# #15#effectiveRadiusWithRespectToWindSpeedsAbove...  313000.0
# #31#bearingOrAzimuth                                   270.0
# #32#bearingOrAzimuth                                     0.0
# #16#effectiveRadiusWithRespectToWindSpeedsAbove...  363000.0
# #5#windSpeedThreshold                                     26
# #33#bearingOrAzimuth                                     0.0
# #34#bearingOrAzimuth                                    90.0
# #17#effectiveRadiusWithRespectToWindSpeedsAbove...   68500.0
# #35#bearingOrAzimuth                                    90.0
# #36#bearingOrAzimuth                                   180.0
# #18#effectiveRadiusWithRespectToWindSpeedsAbove...   57400.0
# #37#bearingOrAzimuth                                   180.0
# #38#bearingOrAzimuth                                   270.0
# #19#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #39#bearingOrAzimuth                                   270.0
# #40#bearingOrAzimuth                                     0.0
# #20#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #6#windSpeedThreshold                                     33
# #41#bearingOrAzimuth                                     0.0
# #42#bearingOrAzimuth                                    90.0
# #21#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #43#bearingOrAzimuth                                    90.0
# #44#bearingOrAzimuth                                   180.0
# #22#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #45#bearingOrAzimuth                                   180.0
# #46#bearingOrAzimuth                                   270.0
# #23#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #47#bearingOrAzimuth                                   270.0
# #48#bearingOrAzimuth                                     0.0
# #24#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0

# %% [markdown]
# This is step 12. Basically every 48 rows is one data for one time step (timePeriod), with the timePeriod being on the beginning.

# %%
df.T[114:162]
# Out:
#                                                            0
# #2#timePeriod                                             12
# #6#meteorologicalAttributeSignificance                     1
# #6#latitude                                             19.6
# #6#longitude                                           120.6
# #3#pressureReducedToMeanSeaLevel                     96900.0
# #7#meteorologicalAttributeSignificance                     3
# #7#latitude                                             20.0
# #7#longitude                                           120.9
# #3#windSpeedAt10M                                       28.8
# #7#windSpeedThreshold                                     18
# #49#bearingOrAzimuth                                     0.0
# #50#bearingOrAzimuth                                    90.0
# #25#effectiveRadiusWithRespectToWindSpeedsAbove...  422300.0
# #51#bearingOrAzimuth                                    90.0
# #52#bearingOrAzimuth                                   180.0
# #26#effectiveRadiusWithRespectToWindSpeedsAbove...  407400.0
# #53#bearingOrAzimuth                                   180.0
# #54#bearingOrAzimuth                                   270.0
# #27#effectiveRadiusWithRespectToWindSpeedsAbove...  257400.0
# #55#bearingOrAzimuth                                   270.0
# #56#bearingOrAzimuth                                     0.0
# #28#effectiveRadiusWithRespectToWindSpeedsAbove...  238900.0
# #8#windSpeedThreshold                                     26
# #57#bearingOrAzimuth                                     0.0
# #58#bearingOrAzimuth                                    90.0
# #29#effectiveRadiusWithRespectToWindSpeedsAbove...   87000.0
# #59#bearingOrAzimuth                                    90.0
# #60#bearingOrAzimuth                                   180.0
# #30#effectiveRadiusWithRespectToWindSpeedsAbove...  101900.0
# #61#bearingOrAzimuth                                   180.0
# #62#bearingOrAzimuth                                   270.0
# #31#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #63#bearingOrAzimuth                                   270.0
# #64#bearingOrAzimuth                                     0.0
# #32#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #9#windSpeedThreshold                                     33
# #65#bearingOrAzimuth                                     0.0
# #66#bearingOrAzimuth                                    90.0
# #33#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #67#bearingOrAzimuth                                    90.0
# #68#bearingOrAzimuth                                   180.0
# #34#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #69#bearingOrAzimuth                                   180.0
# #70#bearingOrAzimuth                                   270.0
# #35#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0
# #71#bearingOrAzimuth                                   270.0
# #72#bearingOrAzimuth                                     0.0
# #36#effectiveRadiusWithRespectToWindSpeedsAbove...       0.0

# %% [markdown]
# From above you can see that the available parameters are:
# - pressureReducedToMeanSeaLevel
# - windSpeedAt10M and
# - effectiveRadiusWithRespectToWindSpeedsAboveThreshold but this one is a bit complicated and it doesn't seem to work correctly with pdbufr

# %% [markdown]
# On top of that you can only read one of them at the same time.

# %%
df1 = pdbufr.read_bufr("tc_test.bufr",
    columns=("stormIdentifier", "latitude", "longitude",
             "timePeriod" ))
df1.head(25)
# Out:
#    stormIdentifier  latitude  longitude  timePeriod
# 0              07W      19.1      121.5           6
# 1              07W      19.5      121.3          12
# 2              07W      20.0      120.9          18
# 3              07W      20.5      120.1          24
# 4              07W      20.4      120.4          30
# 5              07W      21.0      119.7          36
# 6              07W      21.7      119.3          42
# 7              07W      22.7      118.8          48
# 8              07W      24.1      118.4          54
# 9              07W      24.6      119.2          60
# 10             07W      24.8      119.2          66
# 11             07W      29.0      116.4          72
# 12             07W      30.0      116.3          78
# 13             07W      31.2      120.1          84
# 14             07W      33.3      118.6          90
# 15             07W      33.3      118.5          96
# 16             07W      33.3      118.6         102
# 17             07W      34.7      120.1         108
# 18             07W      38.3      117.8         114
# 19             07W      38.3      117.8         120
# 20             07W      38.8      114.8         126
# 21             07W       NaN        NaN         132
# 22             07W       NaN        NaN         138

# %%
df2 = pdbufr.read_bufr("TC/tc_test.bufr",
    columns=("stormIdentifier", "latitude", "longitude",
             "windSpeedAt10M"))
df2
# Out:
#    stormIdentifier  latitude  longitude  windSpeedAt10M
# 0              07W      19.1      121.5            28.3
# 1              07W      19.5      121.3            29.3
# 2              07W      20.0      120.9            28.8
# 3              07W      20.5      120.1            32.4
# 4              07W      20.4      120.4            33.4
# 5              07W      21.0      119.7            47.3
# 6              07W      21.7      119.3            49.4
# 7              07W      22.7      118.8            49.9
# 8              07W      24.1      118.4            46.8
# 9              07W      24.6      119.2            20.1
# 10             07W      24.8      119.2            15.4
# 11             07W      29.0      116.4            13.4
# 12             07W      30.0      116.3            12.9
# 13             07W      31.2      120.1            10.8
# 14             07W      33.3      118.6             9.3
# 15             07W      33.3      118.5             9.3
# 16             07W      33.3      118.6             9.3
# 17             07W      34.7      120.1            11.3
# 18             07W      38.3      117.8            12.3
# 19             07W      38.3      117.8            11.8
# 20             07W      38.8      114.8             9.8
# 21             07W       NaN        NaN             NaN
# 22             07W       NaN        NaN             NaN
# 23             07W      37.6      112.8             6.7

# %%
df3 = pdbufr.read_bufr("TC/tc_test.bufr",
    columns=("stormIdentifier", "latitude", "longitude",
             "pressureReducedToMeanSeaLevel"))
df3
# Out:
#    stormIdentifier  latitude  longitude  pressureReducedToMeanSeaLevel
# 0              07W      18.8      121.1                        96700.0
# 1              07W      19.2      121.0                        96700.0
# 2              07W      19.6      120.6                        96900.0
# 3              07W      20.2      120.3                        96700.0
# 4              07W      20.7      119.8                        96700.0
# 5              07W      21.4      119.3                        95800.0
# 6              07W      21.9      118.8                        95300.0
# 7              07W      23.0      118.4                        95200.0
# 8              07W      24.2      118.1                        95300.0
# 9              07W      25.4      117.4                        97200.0
# 10             07W      27.3      117.0                        98400.0
# 11             07W      28.7      116.2                        98900.0
# 12             07W      30.1      116.0                        99300.0
# 13             07W      31.9      115.5                        99300.0
# 14             07W      32.5      114.6                        99500.0
# 15             07W      33.1      113.9                        99400.0
# 16             07W      33.4      114.0                        99500.0
# 17             07W      34.1      114.7                        99500.0
# 18             07W      35.0      114.1                        99700.0
# 19             07W      35.9      114.3                        99600.0
# 20             07W      35.0      112.7                       100000.0
# 21             07W       NaN        NaN                            NaN
# 22             07W       NaN        NaN                            NaN
# 23             07W      36.1      110.3                       100300.0

# %% [markdown]
# You can now merge these three dataframes to be able to work further.
